# %%
# %pip install accelerate peft transformers trl evaluate torch
# %pip install -U bitsandbytes
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Collecting trl
#   Downloading trl-0.13.0-py3-none-any.whl.metadata (11 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu121)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Collecting datasets>=2.21.0 (from trl)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl) (13.9.4)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.10.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.8.61)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (17.0.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (3.11.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading trl-0.13.0-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.4/293.4 kB 14.2 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.2 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 30.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets, trl, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.9.0 multiprocess-0.70.16 trl-0.13.0 xxhash-3.5.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.1-py3-none-manylinux_2_24_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: torch~=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch~=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch~=2.0->bitsandbytes) (12.8.61)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch~=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch~=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.1-py3-none-manylinux_2_24_x86_64.whl (69.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.1

# %%
from peft import (
    LoraConfig,
    TaskType,
    get_peft_model,
    prepare_model_for_kbit_training,
)
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
    set_seed,
    TrainingArguments,
    PreTrainedTokenizerBase,
    BitsAndBytesConfig,
    TrainerCallback,
    pipeline,
    EarlyStoppingCallback,
    Trainer
)
from trl import (
    RewardTrainer,
    RewardConfig
)
from dataclasses import dataclass
from typing import (
    Any,
    Optional,
    Union
)
from datasets import (
    load_dataset,
    DatasetDict,
)
import numpy as np
import evaluate
import torch
from transformers.utils import PaddingStrategy
from sklearn.model_selection import KFold
import csv
import pandas as pd

# %%
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
def tokenize_function(batch):
    """Tokenize a batch from a reward modelling dataset."""
    new_examples = {
        "input_ids_chosen": [],
        "attention_mask_chosen": [],
        "input_ids_rejected": [],
        "attention_mask_rejected": [],
    }

    for prompt, chosen, rejected in zip(batch["prompt"], batch["chosen"], batch["rejected"]):
        # tokenized_chosen = tokenizer("Source: " + prompt + "\n\nChosen: " + chosen, truncation=True)
        # tokenized_rejected = tokenizer("Source: " + prompt + "\n\Chosen: " + rejected, truncation=True)
        kwargs = {"padding": "max_length", "truncation": True, "max_length": 512, "return_tensors": "pt"}
        chosen_prompt = prompt + '\n' + chosen
        rejected_prompt = prompt + '\n' + rejected
        tokenized_chosen = tokenizer(chosen_prompt, **kwargs)
        tokenized_rejected = tokenizer(rejected_prompt, **kwargs)

        new_examples["input_ids_chosen"].append(tokenized_chosen["input_ids"].squeeze(0))
        new_examples["attention_mask_chosen"].append(tokenized_chosen["attention_mask"].squeeze(0))
        new_examples["input_ids_rejected"].append(tokenized_rejected["input_ids"].squeeze(0))
        new_examples["attention_mask_rejected"].append(tokenized_rejected["attention_mask"].squeeze(0))

    return new_examples

# %%
@dataclass
class RewardDataCollatorWithPadding:
    tokenizer: PreTrainedTokenizerBase
    padding: Union[bool, str, PaddingStrategy] = True
    pad_to_multiple_of: Optional[int] = None
    return_tensors: str = "pt"

    def __call__(self, features: list[dict[str, Any]]) -> dict[str, Any]:
        features_chosen = []
        features_rejected = []
        for feature in features:
            features_chosen.append(
                {
                    "input_ids": feature["input_ids_chosen"],
                    "attention_mask": feature["attention_mask_chosen"],
                }
            )
            features_rejected.append(
                {
                    "input_ids": feature["input_ids_rejected"],
                    "attention_mask": feature["attention_mask_rejected"],
                }
            )
        batch_chosen = self.tokenizer.pad(
            features_chosen,
            padding=self.padding,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors=self.return_tensors,
        )
        batch_rejected = self.tokenizer.pad(
            features_rejected,
            padding=self.padding,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors=self.return_tensors,
        )
        batch = {
            "input_ids_chosen": batch_chosen["input_ids"],
            "attention_mask_chosen": batch_chosen["attention_mask"],
            "input_ids_rejected": batch_rejected["input_ids"],
            "attention_mask_rejected": batch_rejected["attention_mask"],
            "return_loss": True,
        }
        return batch

# %%
model_name = "google-bert/bert-base-uncased"
dataset_name = "reward_data.csv"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
peft_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,
    inference_mode=False,
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias='none',
)

# %%
  quantization_config = BitsAndBytesConfig(
      load_in_4bit=True,
      bnb_4bit_use_double_quant=True,
      bnb_4bit_quant_type="nf4",
      bnb_4bit_compute_dtype=torch.bfloat16
  )

# %%
def model_init():
    if torch.cuda.is_available():
        model = AutoModelForSequenceClassification.from_pretrained(model_name, device_map=device, quantization_config=quantization_config)
        print('loaded GPU')
    else:
        model = AutoModelForSequenceClassification.from_pretrained(model_name)

    model = prepare_model_for_kbit_training(model)
    model = get_peft_model(model, peft_config)
    model.print_trainable_parameters()

    return model

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
dataset = load_dataset("csv", data_files=dataset_name)

ds_train_devtest = dataset['train'].train_test_split(test_size=50, seed=42)

dataset_splits = DatasetDict({
    'train': ds_train_devtest['train'],
    'test': ds_train_devtest['test'],
})

print("Before:\n", dataset)
print("After:\n", dataset_splits)

dataset_splits['test'].to_csv('reward_eval_dataset.csv')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Before:
#  DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 450
#     })
# })
# After:
#  DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 400
#     })
#     test: Dataset({
#         features: ['prompt', 'chosen', 'rejected'],
#         num_rows: 50
#     })
# })
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 4811

# %%
    dataset_splits['train'] = dataset_splits['train'].map(
    tokenize_function,
    batched=True,
    remove_columns=dataset_splits['train'].column_names,
    )

    dataset_splits['test'] = dataset_splits['test'].map(
    tokenize_function,
    batched=True,
    remove_columns=dataset_splits['test'].column_names,
    )

    dataset = dataset_splits["train"]
    test_dataset = dataset_splits["test"]

    print(dataset)
# Out:
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/50 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids_chosen', 'attention_mask_chosen', 'input_ids_rejected', 'attention_mask_rejected'],
#     num_rows: 400
# })

# %%
def compute_metrics(eval_pred):

  accuracy = evaluate.load("accuracy") # Load the accuracy metric here

  preds = np.argmax(eval_pred.predictions, axis=-1)
  labels = eval_pred.label_ids

  return accuracy.compute(predictions=preds, references=labels)

# %%
# # method
# sweep_config = {
#     'method': 'random'
# }

# # hyperparameters
# parameters_dict = {
#     'batch_size': {
#         'values': [8, 16, 32, 64, 80]
#         },
#     'learning_rate': {
#         'values': [5e-5, 4e-5, 3e-5]
#         },
#     'weight_decay': {
#         'values': [0, 0.01, 0.02]
#         },
#     }


# sweep_config['parameters'] = parameters_dict

# %%
# kf = KFold(n_splits=8, shuffle=True, random_state=42)
# fold_results = []

# %%
# def train(config=None):
#   with wandb.init(config=config):
#     # set sweep configuration
#     config = wandb.config

#     model = model_init()

#     # set training arguments
#     training_args = RewardConfig(
#         output_dir='reward_model',
# 	      report_to='wandb',  # Turn on Weights & Biases logging
#         num_train_epochs=1,
#         learning_rate=config.learning_rate,
#         weight_decay=config.weight_decay,
#         per_device_train_batch_size=config.batch_size,
#         per_device_eval_batch_size=config.batch_size,
#         save_strategy='epoch',
#         eval_strategy='epoch',
#         logging_strategy='epoch',
#         center_rewards_coefficient=0.01,
#         load_best_model_at_end=True,
#         remove_unused_columns=False,
#         fp16=True
#     )

#     # define training loop
#     trainer = RewardTrainer(
#         model=model,
#         args=training_args,
#         data_collator=RewardDataCollatorWithPadding(tokenizer=tokenizer),
#         processing_class=tokenizer,
#         train_dataset=dataset,
#         eval_dataset=test_dataset,
#         compute_metrics=compute_metrics
#     )

#     trainer.train_dataset = None
#     trainer.eval_dataset = None

#     for fold, (train_index, val_index) in enumerate(kf.split(dataset)):
#         print(f"Fold {fold + 1}")
#         train_dataset = dataset.select(train_index)
#         val_dataset = dataset.select(val_index)

#         trainer.train_dataset = train_dataset
#         trainer.eval_dataset = val_dataset

#         trainer.train()
#         eval_result = trainer.evaluate()

#         fold_results.append(eval_result)

#     avg_results = {metric: np.mean([result[metric] for result in fold_results]) for metric in fold_results[0]}
#     print("Average results across folds:", avg_results)

# %%
# sweep_id = wandb.sweep(sweep_config, project='reward_model_training')

# %%
# wandb.agent(sweep_id, train, count=20)

# %%
api = wandb.Api()
sweep = api.sweep('d-l-van-thulden-university-of-groningen/reward_model_training/sweeps/k31gw7pm')

best_run = sweep.best_run(order='eval/accuracy')
print(best_run.name)
best_parameters = best_run.config
print(best_parameters)

with open("mycsvfile.csv", "w", newline="") as f:
    w = csv.DictWriter(f, best_parameters.keys())
    w.writeheader()
    w.writerow(best_parameters)
# Out:
# wandb: Sorting runs by -summary_metrics.eval/accuracy
# comfy-sweep-1
# {'bf16': False, 'fp16': True, 'fsdp': [], 'seed': 42, 'tf32': None, 'debug': [], 'optim': 'adamw_torch', 'top_k': 50, 'top_p': 1, 'prefix': None, 'do_eval': True, 'no_cuda': False, 'use_cpu': False, 'do_train': False, 'id2label': {'0': 'LABEL_0', '1': 'LABEL_1'}, 'label2id': {'LABEL_0': 0, 'LABEL_1': 1}, 'run_name': 'reward_model', 'use_ipex': False, 'adafactor': False, 'data_seed': None, 'deepspeed': None, 'do_sample': False, 'hub_token': '<HUB_TOKEN>', 'log_level': 'passive', 'max_steps': -1, 'num_beams': 1, 'ray_scope': 'last', 'report_to': ['wandb'], 'typical_p': 1, 'use_cache': True, 'adam_beta1': 0.9, 'adam_beta2': 0.999, 'batch_size': 80, 'do_predict': False, 'eval_delay': 0, 'eval_steps': None, 'hidden_act': 'gelu', 'is_decoder': False, 'local_rank': 0, 'max_length': None, 'min_length': 0, 'model_type': 'bert', 'optim_args': None, 'output_dir': 'reward_model', 'past_index': -1, 'save_steps': 500, 'vocab_size': 30522, 'ddp_backend': None, 'ddp_timeout': 1800, 'fsdp_config': {'xla': False, 'xla_fsdp_v2': False, 'min_num_params': 0, 'xla_fsdp_grad_ckpt': False}, 'hidden_size': 768, 'label_names': None, 'logging_dir': 'reward_model/runs/Jan21_15-06-57_bd331df5206b', 'peft_config': {'default': {'r': 16, 'bias': 'none', 'revision': None, 'use_dora': False, 'lora_bias': False, 'peft_type': 'LORA', 'task_type': 'SEQ_CLS', 'eva_config': None, 'lora_alpha': 32, 'use_rslora': False, 'auto_mapping': None, 'lora_dropout': 0.05, 'megatron_core': 'megatron.core', 'fan_in_fan_out': False, 'inference_mode': False, 'layers_pattern': None, 'runtime_config': {'ephemeral_gpu_offload': False}, 'target_modules': ['query', 'value'], 'exclude_modules': None, 'megatron_config': None, 'modules_to_save': ['classifier', 'score'], 'init_lora_weights': True, 'layer_replication': None, 'layers_to_transform': None, 'base_model_name_or_path': 'google-bert/bert-base-uncased'}}, 'push_to_hub': False, 'return_dict': True, 'temperature': 1, 'torch_dtype': None, 'torchdynamo': None, 'torchscript': False, 'adam_epsilon': 1e-08, 'bos_token_id': None, 'disable_tqdm': False, 'eos_token_id': None, 'fp16_backend': 'auto', 'hub_model_id': None, 'hub_strategy': 'every_save', 'pad_token_id': 0, 'problem_type': None, 'sep_token_id': None, 'use_bfloat16': False, 'warmup_ratio': 0, 'warmup_steps': 0, 'weight_decay': 0, '_name_or_path': 'google-bert/bert-base-uncased', 'architectures': ['BertForMaskedLM'], 'bad_words_ids': None, 'eval_on_start': False, 'eval_strategy': 'epoch', 'jit_mode_eval': False, 'learning_rate': 5e-05, 'logging_steps': 500, 'max_grad_norm': 1, 'mp_parameters': '', 'output_scores': False, 'save_strategy': 'epoch', 'split_batches': None, 'torch_compile': False, 'tpu_num_cores': None, 'bf16_full_eval': False, 'early_stopping': False, 'fp16_full_eval': False, 'fp16_opt_level': 'O1', 'layer_norm_eps': 1e-12, 'length_penalty': 1, 'tf_legacy_loss': False, 'use_mps_device': False, 'finetuning_task': None, 'group_by_length': False, 'hub_always_push': False, 'num_beam_groups': 1, 'save_only_model': False, 'suppress_tokens': None, 'tokenizer_class': None, 'type_vocab_size': 2, 'dataset_num_proc': None, 'dispatch_batches': None, 'full_determinism': False, 'hub_private_repo': None, 'ignore_data_skip': False, 'log_on_each_node': True, 'logging_strategy': 'epoch', 'num_train_epochs': 1, 'save_safetensors': True, 'save_total_limit': None, 'use_liger_kernel': False, 'ddp_bucket_cap_mb': None, 'diversity_penalty': 0, 'greater_is_better': False, 'initializer_range': 0.02, 'intermediate_size': 3072, 'log_level_replica': 'warning', 'lr_scheduler_type': 'linear', 'num_hidden_layers': 12, 'output_attentions': False, 'push_to_hub_token': '<PUSH_TO_HUB_TOKEN>', 'save_on_each_node': False, 'tpu_metrics_debug': False, 'accelerator_config': {'even_batches': True, 'non_blocking': False, 'split_batches': False, 'dispatch_batches': None, 'use_seedable_sampler': True, 'gradient_accumulation_kwargs': None}, 'batch_eval_metrics': False, 'classifier_dropout': None, 'is_encoder_deco ...

# %%
with open("mycsvfile.csv", "r") as f:
    reader = csv.DictReader(f)
    print(reader)
    reward_config = [row for row in reader][0]

print(reward_config)
# Out:
# <csv.DictReader object at 0x7ea78b4967d0>
# {'bf16': 'False', 'fp16': 'True', 'fsdp': '[]', 'seed': '42', 'tf32': '', 'debug': '[]', 'optim': 'adamw_torch', 'top_k': '50', 'top_p': '1', 'prefix': '', 'do_eval': 'True', 'no_cuda': 'False', 'use_cpu': 'False', 'do_train': 'False', 'id2label': "{'0': 'LABEL_0', '1': 'LABEL_1'}", 'label2id': "{'LABEL_0': 0, 'LABEL_1': 1}", 'run_name': 'reward_model', 'use_ipex': 'False', 'adafactor': 'False', 'data_seed': '', 'deepspeed': '', 'do_sample': 'False', 'hub_token': '<HUB_TOKEN>', 'log_level': 'passive', 'max_steps': '-1', 'num_beams': '1', 'ray_scope': 'last', 'report_to': "['wandb']", 'typical_p': '1', 'use_cache': 'True', 'adam_beta1': '0.9', 'adam_beta2': '0.999', 'batch_size': '80', 'do_predict': 'False', 'eval_delay': '0', 'eval_steps': '', 'hidden_act': 'gelu', 'is_decoder': 'False', 'local_rank': '0', 'max_length': '', 'min_length': '0', 'model_type': 'bert', 'optim_args': '', 'output_dir': 'reward_model', 'past_index': '-1', 'save_steps': '500', 'vocab_size': '30522', 'ddp_backend': '', 'ddp_timeout': '1800', 'fsdp_config': "{'xla': False, 'xla_fsdp_v2': False, 'min_num_params': 0, 'xla_fsdp_grad_ckpt': False}", 'hidden_size': '768', 'label_names': '', 'logging_dir': 'reward_model/runs/Jan21_15-06-57_bd331df5206b', 'peft_config': "{'default': {'r': 16, 'bias': 'none', 'revision': None, 'use_dora': False, 'lora_bias': False, 'peft_type': 'LORA', 'task_type': 'SEQ_CLS', 'eva_config': None, 'lora_alpha': 32, 'use_rslora': False, 'auto_mapping': None, 'lora_dropout': 0.05, 'megatron_core': 'megatron.core', 'fan_in_fan_out': False, 'inference_mode': False, 'layers_pattern': None, 'runtime_config': {'ephemeral_gpu_offload': False}, 'target_modules': ['query', 'value'], 'exclude_modules': None, 'megatron_config': None, 'modules_to_save': ['classifier', 'score'], 'init_lora_weights': True, 'layer_replication': None, 'layers_to_transform': None, 'base_model_name_or_path': 'google-bert/bert-base-uncased'}}", 'push_to_hub': 'False', 'return_dict': 'True', 'temperature': '1', 'torch_dtype': '', 'torchdynamo': '', 'torchscript': 'False', 'adam_epsilon': '1e-08', 'bos_token_id': '', 'disable_tqdm': 'False', 'eos_token_id': '', 'fp16_backend': 'auto', 'hub_model_id': '', 'hub_strategy': 'every_save', 'pad_token_id': '0', 'problem_type': '', 'sep_token_id': '', 'use_bfloat16': 'False', 'warmup_ratio': '0', 'warmup_steps': '0', 'weight_decay': '0', '_name_or_path': 'google-bert/bert-base-uncased', 'architectures': "['BertForMaskedLM']", 'bad_words_ids': '', 'eval_on_start': 'False', 'eval_strategy': 'epoch', 'jit_mode_eval': 'False', 'learning_rate': '5e-05', 'logging_steps': '500', 'max_grad_norm': '1', 'mp_parameters': '', 'output_scores': 'False', 'save_strategy': 'epoch', 'split_batches': '', 'torch_compile': 'False', 'tpu_num_cores': '', 'bf16_full_eval': 'False', 'early_stopping': 'False', 'fp16_full_eval': 'False', 'fp16_opt_level': 'O1', 'layer_norm_eps': '1e-12', 'length_penalty': '1', 'tf_legacy_loss': 'False', 'use_mps_device': 'False', 'finetuning_task': '', 'group_by_length': 'False', 'hub_always_push': 'False', 'num_beam_groups': '1', 'save_only_model': 'False', 'suppress_tokens': '', 'tokenizer_class': '', 'type_vocab_size': '2', 'dataset_num_proc': '', 'dispatch_batches': '', 'full_determinism': 'False', 'hub_private_repo': '', 'ignore_data_skip': 'False', 'log_on_each_node': 'True', 'logging_strategy': 'epoch', 'num_train_epochs': '1', 'save_safetensors': 'True', 'save_total_limit': '', 'use_liger_kernel': 'False', 'ddp_bucket_cap_mb': '', 'diversity_penalty': '0', 'greater_is_better': 'False', 'initializer_range': '0.02', 'intermediate_size': '3072', 'log_level_replica': 'warning', 'lr_scheduler_type': 'linear', 'num_hidden_layers': '12', 'output_attentions': 'False', 'push_to_hub_token': '<PUSH_TO_HUB_TOKEN>', 'save_on_each_node': 'False', 'tpu_metrics_debug': 'False', 'accelerator_config': "{'even_batches': True, 'non_blocking': False, 'split_batches': False, 'dispatch_batches': None, 'use_seedable_sampler': True, 'gr ...

# %%
model = model_init()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google-bert/bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# loaded GPU
# trainable params: 591,362 || all params: 110,075,140 || trainable%: 0.5372

# %%
training_args = RewardConfig(
output_dir="reward_model/bert_config",
learning_rate=float(reward_config['learning_rate']),
num_train_epochs=1,
weight_decay=float(reward_config['weight_decay']),
eval_strategy='epoch',
logging_strategy='epoch',
save_strategy='epoch',
per_device_train_batch_size=int(reward_config['batch_size']),
per_device_eval_batch_size=int(reward_config['batch_size']),
optim=reward_config['optim'],
seed=int(reward_config['seed']),
fp16=reward_config['fp16'],
center_rewards_coefficient=float(0.01),
load_best_model_at_end = True,
save_total_limit = 1,
report_to='wandb'
)

# %%
trainer = RewardTrainer(
model=model,
args=training_args,
train_dataset=dataset,
eval_dataset=test_dataset,
processing_class=tokenizer,
data_collator=RewardDataCollatorWithPadding(tokenizer=tokenizer),
compute_metrics=compute_metrics,
)

# %%
trainer.train_dataset = None
trainer.eval_dataset = None

# %%
kf = KFold(n_splits=8, shuffle=True, random_state=42)
epoch_results = []
fold_results = []

# %%
# for i in range(3):
for fold, (train_index, val_index) in enumerate(kf.split(dataset)):
  print(f"Fold {fold + 1}")

  # model = model_init()

  # trainer = RewardTrainer(
  #   model=model,
  #   args=training_args,
  #   train_dataset=dataset,
  #   eval_dataset=test_dataset,
  #   processing_class=tokenizer,
  #   data_collator=RewardDataCollatorWithPadding(tokenizer=tokenizer),
  #   compute_metrics=compute_metrics,
  #   )

  train_dataset = dataset.select(train_index)
  val_dataset = dataset.select(val_index)

  trainer.train_dataset = train_dataset
  trainer.eval_dataset = val_dataset

  trainer.train()
  eval_result = trainer.evaluate()

  fold_results.append(eval_result)

  avg_results = {metric: np.mean([result[metric] for result in fold_results]) for metric in fold_results[0]}
  print("Average results across folds:", avg_results)
  epoch_results.append(avg_results)

print("Average results across epochs:", epoch_results)
# Out:
# Fold 1
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.707700</td>
#       <td>0.699289</td>
#       <td>0.400000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] you know i have haneve admire president │ [CLS] you know i have haneve admire          │ [0.4933, 0.5067] │
# │ nixon. i think he was a great man. [SEP]      │ president nixon. i think he ' s a great      │                  │
# │                                               │ leader. [SEP]                                │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] darren drag that crashpad to center     │ [CLS] darren drag that crashpad to center    │ [0.4933, 0.5067] │
# │ mats and. darren is on the floor. [SEP]       │ mats and. darren puts it down. [SEP]         │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] righteousnesses he have fill for you.   │ [CLS] righteousnesses he have fill for you.  │ [0.4892, 0.5108] │
# │ and he hath redeemed you from all your sins.  │ and he hath redeemed you from your enemies.  │                  │
# │ [SEP]                                         │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] okay i do see you. i do see you, i see  │ [CLS] okay i do see you. i do see you, i do  │ [0.4969, 0.5031] │
# │ you. [SEP]                                    │ see you. [SEP]                               │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] you know i have haneve admire president │ [CLS] you know i have haneve admire          │ [0.5002, 0.4998] │
# │ nixon. i think he was a great man. [SEP]      │ president nixon. i think he ' s a great      │                  │
# │                                               │ leader. [SEP]                                │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] darren drag that crashpad to center     │ [CLS] darren drag that crashpad to center    │ [0.5035, 0.4965] │
# │ mats and. darren is on the floor. [SEP]       │ mats and. darren puts it down. [SEP]         │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] righteousnesses he have fill for you.   │ [CLS] righteousnesses he have fill for you.  │ [0.5017, 0.4983] │
# │ and he hath redeemed you from all your sins.  │ and he hath redeemed you from your enemies.  │                  │
# │ [SEP]                                         │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] okay i do see you. i do see you, i see  │ [CLS] okay i do see you. i do see you, i do  │ [0.4998, 0.5002] │
# │ you. [SEP]                                    │ see you. [SEP]                               │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.6992886066436768, 'eval_accuracy': 0.4, 'eval_runtime': 2.062, 'eval_samples_per_second': 24.249, 'eval_steps_per_second': 0.485, 'epoch': 1.0}
# Fold 2
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.703800</td>
#       <td>0.696560</td>
#       <td>0.440000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] and he do know what do situation. he do │ [CLS] and he do know what do situation. he   │ [0.4908, 0.5092] │
# │ know what do situation. [SEP]                 │ do know what to do. [SEP]                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] oh no i could go. i don ' t want to go  │ [CLS] oh no i could go. i don ' t want to    │ [0.4568, 0.5432] │
# │ to the concert. [SEP]                         │ go. [SEP]                                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] we stripped sides and everything. we    │ [CLS] we stripped sides and everything. we   │ [0.4993, 0.5007] │
# │ had a lot of work to do to prepare for the    │ had a lot of work to do. [SEP]               │                  │
# │ big party. [SEP]                              │                                              │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] if you have studio apartment you are    │ [CLS] if you have studio apartment you are   │ [0.4925, 0.5075] │
# │ stuck it. you can ' t do anything about it.   │ stuck it. you can ' t do anything about it,  │                  │
# │ [SEP]                                         │ but that doesn ' t mean you can ' t make it  │                  │
# │                                               │ work. [SEP]                                  │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] and he do know what do situation. he do │ [CLS] and he do know what do situation. he   │ [0.5017, 0.4983] │
# │ know what do situation. [SEP]                 │ do know what to do. [SEP]                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] oh no i could go. i don ' t want to go  │ [CLS] oh no i could go. i don ' t want to    │ [0.4955, 0.5045] │
# │ to the concert. [SEP]                         │ go. [SEP]                                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] we stripped sides and everything. we    │ [CLS] we stripped sides and everything. we   │ [0.4828, 0.5172] │
# │ had a lot of work to do to prepare for the    │ had a lot of work to do. [SEP]               │                  │
# │ big party. [SEP]                              │                                              │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] if you have studio apartment you are    │ [CLS] if you have studio apartment you are   │ [0.5054, 0.4946] │
# │ stuck it. you can ' t do anything about it.   │ stuck it. you can ' t do anything about it,  │                  │
# │ [SEP]                                         │ but that doesn ' t mean you can ' t make it  │                  │
# │                                               │ work. [SEP]                                  │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.6979241669178009, 'eval_accuracy': 0.42000000000000004, 'eval_runtime': 2.01785, 'eval_samples_per_second': 24.790999999999997, 'eval_steps_per_second': 0.496, 'epoch': 1.0}
# Fold 3
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.701900</td>
#       <td>0.696891</td>
#       <td>0.420000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] i would never be handle it. i would be  │ [CLS] i would never be handle it. i would be │ [0.4833, 0.5167] │
# │ too scared. [SEP]                             │ too scared to do it. [SEP]                   │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] and he do know what do situation. he do │ [CLS] and he do know what do situation. he   │ [0.5046, 0.4954] │
# │ know what to do in the situation. [SEP]       │ do know what to do. [SEP]                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] full cut up tomatoes and. the woman is  │ [CLS] full cut up tomatoes and. the woman is │ [0.5524, 0.4476] │
# │ making a salad with the tomatoes. [SEP]       │ slicing an onion. [SEP]                      │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] i knew i do like guys. i am just not    │ [CLS] i knew i do like guys. i am just not   │ [0.4931, 0.5069] │
# │ sure how to ask for them. [SEP]               │ sure how to express it. [SEP]                │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] i would never be handle it. i would be  │ [CLS] i would never be handle it. i would be │ [0.5015, 0.4985] │
# │ too scared. [SEP]                             │ too scared to do it. [SEP]                   │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] and he do know what do situation. he do │ [CLS] and he do know what do situation. he   │ [0.4964, 0.5036] │
# │ know what to do in the situation. [SEP]       │ do know what to do. [SEP]                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] full cut up tomatoes and. the woman is  │ [CLS] full cut up tomatoes and. the woman is │ [0.4952, 0.5048] │
# │ making a salad with the tomatoes. [SEP]       │ slicing an onion. [SEP]                      │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] i knew i do like guys. i am just not    │ [CLS] i knew i do like guys. i am just not   │ [0.4886, 0.5114] │
# │ sure how to ask for them. [SEP]               │ sure how to express it. [SEP]                │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.6975799202919006, 'eval_accuracy': 0.42, 'eval_runtime': 2.0362666666666667, 'eval_samples_per_second': 24.566999999999997, 'eval_steps_per_second': 0.49133333333333334, 'epoch': 1.0}
# Fold 4
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:19, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.695600</td>
#       <td>0.694000</td>
#       <td>0.580000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] i thought this was most thing i heard   │ [CLS] i thought this was most thing i heard  │ [0.5109, 0.4891] │
# │ in my life. i was blown away. [SEP]           │ in my life. i was very surprised. [SEP]      │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] he has theories draw at art parallels.  │ [CLS] he has theories draw at art parallels. │ [0.545, 0.455]   │
# │ he is a theorist. [SEP]                       │ he is a philosopher. [SEP]                   │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you know i it be just. i know i be      │ [CLS] you know i it be just. i know i be     │ [0.4586, 0.5414] │
# │ just. [SEP]                                   │ just. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] but you can not go walmart. you can not │ [CLS] but you can not go walmart. you can    │ [0.5084, 0.4916] │
# │ go to the store. [SEP]                        │ not go to the store, you can not go to the   │                  │
# │                                               │ store. [SEP]                                 │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] i thought this was most thing i heard   │ [CLS] i thought this was most thing i heard  │ [0.5019, 0.4981] │
# │ in my life. i was blown away. [SEP]           │ in my life. i was very surprised. [SEP]      │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] he has theories draw at art parallels.  │ [CLS] he has theories draw at art parallels. │ [0.4957, 0.5043] │
# │ he is a theorist. [SEP]                       │ he is a philosopher. [SEP]                   │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you know i it be just. i know i be      │ [CLS] you know i it be just. i know i be     │ [0.5, 0.5]       │
# │ just. [SEP]                                   │ just. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] but you can not go walmart. you can not │ [CLS] but you can not go walmart. you can    │ [0.4919, 0.5081] │
# │ go to the store. [SEP]                        │ not go to the store, you can not go to the   │                  │
# │                                               │ store. [SEP]                                 │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.6966848224401474, 'eval_accuracy': 0.45999999999999996, 'eval_runtime': 2.015025, 'eval_samples_per_second': 24.831249999999997, 'eval_steps_per_second': 0.4965, 'epoch': 1.0}
# Fold 5
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:19, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.699000</td>
#       <td>0.691674</td>
#       <td>0.520000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] well we get sixhundred dollars month.   │ [CLS] well we get sixhundred dollars month.  │ [0.5192, 0.4808] │
# │ we are rich. [SEP]                            │ we are happy with it. [SEP]                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] yeah there is three lake there. it ' s  │ [CLS] yeah there is three lake there. it ' s │ [0.5147, 0.4853] │
# │ a great place to go hiking. [SEP]             │ a great place to go fishing. [SEP]           │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] i mean they do stuff. i mean, they ' re │ [CLS] i mean they do stuff. i mean, they '   │ [0.4964, 0.5036] │
# │ just a bunch of weirdos. [SEP]                │ re just a bunch of people. [SEP]             │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] and make it standard habits. and make   │ [CLS] and make it standard habits. and make  │ [0.4937, 0.5063] │
# │ it a habit. [SEP]                             │ it a standard habit. [SEP]                   │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] well we get sixhundred dollars month.   │ [CLS] well we get sixhundred dollars month.  │ [0.5055, 0.4945] │
# │ we are rich. [SEP]                            │ we are happy with it. [SEP]                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] yeah there is three lake there. it ' s  │ [CLS] yeah there is three lake there. it ' s │ [0.5023, 0.4977] │
# │ a great place to go hiking. [SEP]             │ a great place to go fishing. [SEP]           │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] i mean they do stuff. i mean, they ' re │ [CLS] i mean they do stuff. i mean, they '   │ [0.4987, 0.5013] │
# │ just a bunch of weirdos. [SEP]                │ re just a bunch of people. [SEP]             │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] and make it standard habits. and make   │ [CLS] and make it standard habits. and make  │ [0.499, 0.501]   │
# │ it a habit. [SEP]                             │ it a standard habit. [SEP]                   │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.695682680606842, 'eval_accuracy': 0.472, 'eval_runtime': 2.01462, 'eval_samples_per_second': 24.8328, 'eval_steps_per_second': 0.49660000000000004, 'epoch': 1.0}
# Fold 6
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.699200</td>
#       <td>0.693344</td>
#       <td>0.580000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] i will get common denominator. i will   │ [CLS] i will get common denominator. i will  │ [0.4654, 0.5346] │
# │ get common denominator. [SEP]                 │ get the common denominator. [SEP]            │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you can do it way. you can do it any    │ [CLS] you can do it way. you can do it.      │ [0.4719, 0.5281] │
# │ way you want. [SEP]                           │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] well she never did anything it. she was │ [CLS] well she never did anything it. she    │ [0.501, 0.499]   │
# │ always so busy. [SEP]                         │ was a good girl. [SEP]                       │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] well i use come out. i don ' t know how │ [CLS] well i use come out. i don ' t like to │ [0.5225, 0.4775] │
# │ to spell it. [SEP]                            │ come out. [SEP]                              │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] i will get common denominator. i will   │ [CLS] i will get common denominator. i will  │ [0.5, 0.5]       │
# │ get common denominator. [SEP]                 │ get the common denominator. [SEP]            │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you can do it way. you can do it any    │ [CLS] you can do it way. you can do it.      │ [0.4982, 0.5018] │
# │ way you want. [SEP]                           │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] well she never did anything it. she was │ [CLS] well she never did anything it. she    │ [0.5064, 0.4936] │
# │ always so busy. [SEP]                         │ was a good girl. [SEP]                       │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] well i use come out. i don ' t know how │ [CLS] well i use come out. i don ' t like to │ [0.5001, 0.4999] │
# │ to spell it. [SEP]                            │ come out. [SEP]                              │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.6952929099400839, 'eval_accuracy': 0.49, 'eval_runtime': 2.01375, 'eval_samples_per_second': 24.841166666666666, 'eval_steps_per_second': 0.4968333333333333, 'epoch': 1.0}
# Fold 7
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.689200</td>
#       <td>0.697023</td>
#       <td>0.400000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] they need become somewhat               │ [CLS] they need become somewhat              │ [0.496, 0.504]   │
# │ selfsufficient. they need to learn how to     │ selfsufficient. they need to learn how to    │                  │
# │ cook for themselves. [SEP]                    │ cook. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you can still hear planes. it ' s too   │ [CLS] you can still hear planes. the airport │ [0.4923, 0.5077] │
# │ close to the city. [SEP]                      │ is too far away. [SEP]                       │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you know you know she is. she is a good │ [CLS] you know you know she is. she is a     │ [0.5122, 0.4878] │
# │ girl and you know it. [SEP]                   │ slut. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] just make you get enough air. you ' ll  │ [CLS] just make you get enough air. you ' ll │ [0.4882, 0.5118] │
# │ be alright. [SEP]                             │ be fine. [SEP]                               │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] they need become somewhat               │ [CLS] they need become somewhat              │ [0.5004, 0.4996] │
# │ selfsufficient. they need to learn how to     │ selfsufficient. they need to learn how to    │                  │
# │ cook for themselves. [SEP]                    │ cook. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you can still hear planes. it ' s too   │ [CLS] you can still hear planes. the airport │ [0.4977, 0.5023] │
# │ close to the city. [SEP]                      │ is too far away. [SEP]                       │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] you know you know she is. she is a good │ [CLS] you know you know she is. she is a     │ [0.4824, 0.5176] │
# │ girl and you know it. [SEP]                   │ slut. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] just make you get enough air. you ' ll  │ [CLS] just make you get enough air. you ' ll │ [0.499, 0.501]   │
# │ be alright. [SEP]                             │ be fine. [SEP]                               │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:22]
#     </div>
# Average results across folds: {'eval_loss': 0.6955400790487017, 'eval_accuracy': 0.47714285714285715, 'eval_runtime': 2.011185714285714, 'eval_samples_per_second': 24.87142857142857, 'eval_steps_per_second': 0.4974285714285714, 'epoch': 1.0}
# Fold 8
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.696000</td>
#       <td>0.692433</td>
#       <td>0.480000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] they need become somewhat               │ [CLS] they need become somewhat              │ [0.5087, 0.4913] │
# │ selfsufficient. they need to learn how to     │ selfsufficient. they need to learn how to    │                  │
# │ cook and clean. [SEP]                         │ cook. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] they film movie at oakland catholic.    │ [CLS] they film movie at oakland catholic.   │ [0.4946, 0.5054] │
# │ they are filming a movie. [SEP]               │ they film movie at oakland catholic in       │                  │
# │                                               │ california. [SEP]                            │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] she need get into some campus group.    │ [CLS] she need get into some campus group.   │ [0.4498, 0.5502] │
# │ she is a student at the university. [SEP]     │ she is a student at a community college.     │                  │
# │                                               │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] they film movie at oakland catholic.    │ [CLS] they film movie at oakland catholic.   │ [0.4392, 0.5608] │
# │ they film movie at oakland catholic. [SEP]    │ they film movie at oakland catholic in       │                  │
# │                                               │ california. [SEP]                            │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] they need become somewhat               │ [CLS] they need become somewhat              │ [0.5021, 0.4979] │
# │ selfsufficient. they need to learn how to     │ selfsufficient. they need to learn how to    │                  │
# │ cook and clean. [SEP]                         │ cook. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] they film movie at oakland catholic.    │ [CLS] they film movie at oakland catholic.   │ [0.4915, 0.5085] │
# │ they are filming a movie. [SEP]               │ they film movie at oakland catholic in       │                  │
# │                                               │ california. [SEP]                            │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] she need get into some campus group.    │ [CLS] she need get into some campus group.   │ [0.4957, 0.5043] │
# │ she is a student at the university. [SEP]     │ she is a student at a community college.     │                  │
# │                                               │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] they film movie at oakland catholic.    │ [CLS] they film movie at oakland catholic.   │ [0.502, 0.498]   │
# │ they film movie at oakland catholic. [SEP]    │ they film movie at oakland catholic in       │                  │
# │                                               │ california. [SEP]                            │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# Average results across folds: {'eval_loss': 0.6951517313718796, 'eval_accuracy': 0.47750000000000004, 'eval_runtime': 2.0157499999999997, 'eval_samples_per_second': 24.814749999999997, 'eval_steps_per_second': 0.49624999999999997, 'epoch': 1.0}
# Average results across epochs: [{'eval_loss': 0.6992886066436768, 'eval_accuracy': 0.4, 'eval_runtime': 2.062, 'eval_samples_per_second': 24.249, 'eval_steps_per_second': 0.485, 'epoch': 1.0}, {'eval_loss': 0.6979241669178009, 'eval_accuracy': 0.42000000000000004, 'eval_runtime': 2.01785, 'eval_samples_per_second': 24.790999999999997, 'eval_steps_per_second': 0.496, 'epoch': 1.0}, {'eval_loss': 0.6975799202919006, 'eval_accuracy': 0.42, 'eval_runtime': 2.0362666666666667, 'eval_samples_per_second': 24.566999999999997, 'eval_steps_per_second': 0.49133333333333334, 'epoch': 1.0}, {'eval_loss': 0.6966848224401474, 'eval_accuracy': 0.45999999999999996, 'eval_runtime': 2.015025, 'eval_samples_per_second': 24.831249999999997, 'eval_steps_per_second': 0.4965, 'epoch': 1.0}, {'eval_loss': 0.695682680606842, 'eval_accuracy': 0.472, 'eval_runtime': 2.01462, 'eval_samples_per_second': 24.8328, 'eval_steps_per_second': 0.49660000000000004, 'epoch': 1.0}, {'eval_loss': 0.6952929099400839, 'eval_accuracy': 0.49, 'eval_runtime': 2.01375, 'eval_samples_per_second': 24.841166666666666, 'eval_steps_per_second': 0.4968333333333333, 'epoch': 1.0}, {'eval_loss': 0.6955400790487017, 'eval_accuracy': 0.47714285714285715, 'eval_runtime': 2.011185714285714, 'eval_samples_per_second': 24.87142857142857, 'eval_steps_per_second': 0.4974285714285714, 'epoch': 1.0}, {'eval_loss': 0.6951517313718796, 'eval_accuracy': 0.47750000000000004, 'eval_runtime': 2.0157499999999997, 'eval_samples_per_second': 24.814749999999997, 'eval_steps_per_second': 0.49624999999999997, 'epoch': 1.0}]

# %%
metrics = trainer.evaluate()
print(metrics)
eval_accuracy = metrics["eval_accuracy"] * 100
print(f"Evaluation Accuracy: {eval_accuracy: .2f}%")
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] they need become somewhat               │ [CLS] they need become somewhat              │ [0.5021, 0.4979] │
# │ selfsufficient. they need to learn how to     │ selfsufficient. they need to learn how to    │                  │
# │ cook and clean. [SEP]                         │ cook. [SEP]                                  │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] they film movie at oakland catholic.    │ [CLS] they film movie at oakland catholic.   │ [0.4915, 0.5085] │
# │ they are filming a movie. [SEP]               │ they film movie at oakland catholic in       │                  │
# │                                               │ california. [SEP]                            │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] she need get into some campus group.    │ [CLS] she need get into some campus group.   │ [0.4957, 0.5043] │
# │ she is a student at the university. [SEP]     │ she is a student at a community college.     │                  │
# │                                               │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] they film movie at oakland catholic.    │ [CLS] they film movie at oakland catholic.   │ [0.502, 0.498]   │
# │ they film movie at oakland catholic. [SEP]    │ they film movie at oakland catholic in       │                  │
# │                                               │ california. [SEP]                            │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='2' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:09]
#     </div>
# {'eval_loss': 0.6924332976341248, 'eval_accuracy': 0.48, 'eval_runtime': 1.9834, 'eval_samples_per_second': 25.209, 'eval_steps_per_second': 0.504, 'epoch': 1.0}
# Evaluation Accuracy:  48.00%

# %%
trainer.eval_dataset = test_dataset
trainer.evaluate()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ chosen_text                                   ┃ rejected_text                                ┃ logits           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ [CLS] it do matter you can keep her hand      │ [CLS] it do matter you can keep her hand     │ [0.4999, 0.5001] │
# │ grip. you ' re not strong enough to hold her. │ grip. you ' re not strong enough to do it.   │                  │
# │ [SEP]                                         │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] i do not need it divin. i do not want   │ [CLS] i do not need it divin. i do not need  │ [0.5013, 0.4987] │
# │ it. [SEP]                                     │ it. [SEP]                                    │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] he was here two weeks and i miss him.   │ [CLS] he was here two weeks and i miss him.  │ [0.5088, 0.4912] │
# │ he is a great person. [SEP]                   │ he is a great person and a good friend.      │                  │
# │                                               │ [SEP]                                        │                  │
# ├───────────────────────────────────────────────┼──────────────────────────────────────────────┼──────────────────┤
# │ [CLS] because it be get point. i like to play │ [CLS] because it be get point. i like to     │ [0.4949, 0.5051] │
# │ the guitar. [SEP]                             │ play a game. [SEP]                           │                  │
# └───────────────────────────────────────────────┴──────────────────────────────────────────────┴──────────────────┘
#     <div>
#
#       <progress value='3' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:15]
#     </div>
# {'eval_loss': 0.6946930885314941,
#  'eval_accuracy': 0.46,
#  'eval_runtime': 1.9582,
#  'eval_samples_per_second': 25.533,
#  'eval_steps_per_second': 0.511,
#  'epoch': 1.0}

# %%
model.save_pretrained("/content/reward_model/")
tokenizer.save_pretrained("/content/reward_model/tokenizer")

# %%
# !zip -r /content/reward_model.zip /content/reward_model

# %%
test_dataset_raw = load_dataset("csv", data_files='reward_eval_dataset.csv', split='train')
test_dataset_raw
# Out:
# Dataset({
#     features: ['prompt', 'chosen', 'rejected'],
#     num_rows: 50
# })

# %%
sentiment_pipe = pipeline(
    "sentiment-analysis", model=model, tokenizer=tokenizer
)
# Out:
# Device set to use cuda:0
# The model 'PeftModelForSequenceClassification' is not supported for sentiment-analysis. Supported models are ['AlbertForSequenceClassification', 'BartForSequenceClassification', 'BertForSequenceClassification', 'BigBirdForSequenceClassification', 'BigBirdPegasusForSequenceClassification', 'BioGptForSequenceClassification', 'BloomForSequenceClassification', 'CamembertForSequenceClassification', 'CanineForSequenceClassification', 'LlamaForSequenceClassification', 'ConvBertForSequenceClassification', 'CTRLForSequenceClassification', 'Data2VecTextForSequenceClassification', 'DebertaForSequenceClassification', 'DebertaV2ForSequenceClassification', 'DistilBertForSequenceClassification', 'ElectraForSequenceClassification', 'ErnieForSequenceClassification', 'ErnieMForSequenceClassification', 'EsmForSequenceClassification', 'FalconForSequenceClassification', 'FlaubertForSequenceClassification', 'FNetForSequenceClassification', 'FunnelForSequenceClassification', 'GemmaForSequenceClassification', 'Gemma2ForSequenceClassification', 'GlmForSequenceClassification', 'GPT2ForSequenceClassification', 'GPT2ForSequenceClassification', 'GPTBigCodeForSequenceClassification', 'GPTNeoForSequenceClassification', 'GPTNeoXForSequenceClassification', 'GPTJForSequenceClassification', 'IBertForSequenceClassification', 'JambaForSequenceClassification', 'JetMoeForSequenceClassification', 'LayoutLMForSequenceClassification', 'LayoutLMv2ForSequenceClassification', 'LayoutLMv3ForSequenceClassification', 'LEDForSequenceClassification', 'LiltForSequenceClassification', 'LlamaForSequenceClassification', 'LongformerForSequenceClassification', 'LukeForSequenceClassification', 'MarkupLMForSequenceClassification', 'MBartForSequenceClassification', 'MegaForSequenceClassification', 'MegatronBertForSequenceClassification', 'MistralForSequenceClassification', 'MixtralForSequenceClassification', 'MobileBertForSequenceClassification', 'MPNetForSequenceClassification', 'MptForSequenceClassification', 'MraForSequenceClassification', 'MT5ForSequenceClassification', 'MvpForSequenceClassification', 'NemotronForSequenceClassification', 'NezhaForSequenceClassification', 'NystromformerForSequenceClassification', 'OpenLlamaForSequenceClassification', 'OpenAIGPTForSequenceClassification', 'OPTForSequenceClassification', 'PerceiverForSequenceClassification', 'PersimmonForSequenceClassification', 'PhiForSequenceClassification', 'Phi3ForSequenceClassification', 'PhimoeForSequenceClassification', 'PLBartForSequenceClassification', 'QDQBertForSequenceClassification', 'Qwen2ForSequenceClassification', 'Qwen2MoeForSequenceClassification', 'ReformerForSequenceClassification', 'RemBertForSequenceClassification', 'RobertaForSequenceClassification', 'RobertaPreLayerNormForSequenceClassification', 'RoCBertForSequenceClassification', 'RoFormerForSequenceClassification', 'SqueezeBertForSequenceClassification', 'StableLmForSequenceClassification', 'Starcoder2ForSequenceClassification', 'T5ForSequenceClassification', 'TapasForSequenceClassification', 'TransfoXLForSequenceClassification', 'UMT5ForSequenceClassification', 'XLMForSequenceClassification', 'XLMRobertaForSequenceClassification', 'XLMRobertaXLForSequenceClassification', 'XLNetForSequenceClassification', 'XmodForSequenceClassification', 'YosoForSequenceClassification', 'ZambaForSequenceClassification'].

# %%
sent_kwargs = {"top_k": None, "function_to_apply": "none", "return_all_scores": True, "batch_size": 1}

# %%
win = 0
loss = 0
game_data = dict()
game_data['prompt'] = []
game_data['chosen'] = []
game_data['rejected'] = []
game_data['chosen_reward'] = []
game_data['rejected_reward'] = []
game_data['win'] = []
game_data['loss'] = []

for i in range(len(test_dataset_raw['prompt'])):

    prompt = test_dataset_raw['prompt'][i]
    chosen = test_dataset_raw['chosen'][i]
    rejected = test_dataset_raw['rejected'][i]

    chosen_text = prompt + '\n' + chosen
    chosen_output = sentiment_pipe(chosen_text, **sent_kwargs)
    chosen_reward = [output["score"] for output in chosen_output][0]

    rejected_text = prompt + '\n' + rejected
    rejected_output = sentiment_pipe(rejected_text, **sent_kwargs)
    rejected_reward = [output["score"] for output in rejected_output][0]

    if chosen_reward > rejected_reward:
        # print("Chosen is better")
        win += 1
        won = True
        lost = False
    else:
        # print("Rejected is better")
        loss += 1
        won = False
        lost = True

    game_data['prompt'].append(prompt)
    game_data['chosen'].append(chosen)
    game_data['rejected'].append(rejected)
    game_data['chosen_reward'].append(chosen_reward)
    game_data['rejected_reward'].append(rejected_reward)
    game_data['win'].append(won)
    game_data['loss'].append(lost)

ratio = win / (win + loss)
print(ratio)
print(win)
print(loss)

print(game_data)

df_results = pd.DataFrame(game_data)
df_results.to_csv('reward_results.csv')
df_results
# Out:
# 0.5
# 25
# 25
# {'prompt': ['It do matter you can keep her hand grip.', 'I do not need it divin.', 'He was here two weeks and i miss him.', 'Because it be get point.', 'You know i have haneve admire president nixon.', 'And they give you they will mail you reimbursements.', 'The people begin plead jesus to leave their region.', 'And we stayed couples years.', 'I will have jerry get them.', 'But you can not go walmart.', 'I do not need it divin.', 'Only heat you have in this room is one register there.', 'Do not fill your bag dear.', 'If you have studio apartment you are stuck it.', 'Hey who bought green cake.', 'I want make sure now.', 'And you turn it and put chocolate side.', 'And i guess he really go.', 'I do not need it divin.', 'Yes they put stuff that was three times money.', 'If you have studio apartment you are stuck it.', 'You can still hear planes.', 'And he comes the cafeterias.', 'I ate today than i have week long though.', 'I have much distance between us.', 'Do not make fun me.', 'And that it sound but it be hard do.', 'Even though navys threw you out.', 'I think though it is neat watch them.', 'Turn it pours the water through.', 'Yeah i go threehundred pounds days.', 'She come and sit in restaurant.', 'And doors are open house come two dogs.', 'And parts will be lot less than you thought.', 'I mean these is drawing points.', 'And get it set up.', 'What do you want drink bernard.', 'Even though navys threw you out.', 'Oh no i could go.', 'I mean they can make mistakes.', 'Well she never did anything it.', 'I of want hang out though.', 'He was like really and leave.', 'Well he should just go gas station.', 'Do give the answer because you are denying them learning.', 'We go the roads while.', 'I want get these books.', 'And we report how sales we had and they.', 'I want get these books.', 'I just played basketballs main beach.'], 'chosen': ["You're not strong enough to hold her.", 'I do not want it.', 'He is a great person.', 'I like to play the guitar.', 'i think he was a great leader.', 'They are a good company and they will help you.', 'jesus is unable to leave.', 'We were happy to be together.', 'Jerry is a good person.', 'You can not go to the store, you can not go to the store.', 'I do not need it.', 'The room is so cold.', 'You will be too full to walk.', "You can't do anything about it, but that doesn't mean you can't do something about it.", 'I bought the green one.', "I don't want to make any mistakes.", 'And you put it on top of ice cream.', 'I guess he really went.', 'I do not want it.', 'They put a lot of money in it.', "You can't do anything about it, but that doesn't mean you can't do something about it.", 'The airport is too close to the building.', 'He has a lot of friends there.', 'I was hungry today.', "I can't see him often.", 'I am not a joke.', "It's a lot of work to do.", 'You were still a good guy.', 'I like watching them do tricks.', 'The water pours from the faucet to the sink.', "I'm a big eater.", 'She was waiting for her friend to arrive.', 'And the dogs are in a dog park.', 'You will have a great time playing the game.', "I don't know how to draw.", "I'm going to try it.", 'I want a glass of wine.', 'You were still a sailor.', "I don't want to go to the concert.", 'They are human beings.', 'She was always so busy.', "I don't know if I want to go out tonight.", 'He was a big man and it was hard for him to fit in.', 'He needs to get some fuel.', 'You are a jerk to them.', 'We go the roads for a long time.', 'I am going to the book store.', 'They are a company that reports.', 'I want to read them.', 'I had a good time.'], 'rejected': ["You're not strong enough to do it.", 'I do not need it.', 'He is a great person and a good friend.', 'I like to play a game.', "i think he's a great leader.", 'They are a good company.', 'jesus is unable to leave and begins to scream at the people.', 'We were happy with our decision.', 'Jerry is a good guy.', 'You can not go to the store, because you are not a citizen.', 'I ...
#                                                prompt  \
# 0            It do matter you can keep her hand grip.
# 1                             I do not need it divin.
# 2               He was here two weeks and i miss him.
# 3                            Because it be get point.
# 4      You know i have haneve admire president nixon.
# 5   And they give you they will mail you reimburse...
# 6   The people begin plead jesus to leave their re...
# 7                        And we stayed couples years.
# 8                         I will have jerry get them.
# 9                         But you can not go walmart.
# 10                            I do not need it divin.
# 11  Only heat you have in this room is one registe...
# 12                         Do not fill your bag dear.
# 13     If you have studio apartment you are stuck it.
# 14                         Hey who bought green cake.
# 15                              I want make sure now.
# 16            And you turn it and put chocolate side.
# 17                          And i guess he really go.
# 18                            I do not need it divin.
# 19     Yes they put stuff that was three times money.
# 20     If you have studio apartment you are stuck it.
# 21                         You can still hear planes.
# 22                       And he comes the cafeterias.
# 23          I ate today than i have week long though.
# 24                   I have much distance between us.
# 25                                Do not make fun me.
# 26               And that it sound but it be hard do.
# 27                   Even though navys threw you out.
# 28              I think though it is neat watch them.
# 29                   Turn it pours the water through.
# 30                Yeah i go threehundred pounds days.
# 31                    She come and sit in restaurant.
# 32            And doors are open house come two dogs.
# 33       And parts will be lot less than you thought.
# 34                    I mean these is drawing points.
# 35                                 And get it set up.
# 36                    What do you want drink bernard.
# 37                   Even though navys threw you out.
# 38                                  Oh no i could go.
# 39                     I mean they can make mistakes.
# 40                    Well she never did anything it.
# 41                         I of want hang out though.
# 42                      He was like really and leave.
# 43                Well he should just go gas station.
# 44  Do give the answer because you are denying the...
# 45                             We go the roads while.
# 46                            I want get these books.
# 47           And we report how sales we had and they.
# 48                            I want get these books.
# 49              I just played basketballs main beach.
#
#                                                chosen  \
# 0               You're not strong enough to hold her.
# 1                                   I do not want it.
# 2                               He is a great person.
# 3                          I like to play the guitar.
# 4                      i think he was a great leader.
# 5     They are a good company and they will help you.
# 6                           jesus is unable to leave.
# 7                       We were happy to be together.
# 8                             Jerry is a good person.
# 9   You can not go to the store, you can not go to...
# 10                                  I do not need it.
# 11                               The room is so cold.
# 12                      You will be too full to walk.
# 13  You can't do anything about it, but that doesn...
# 14                            I bought the green one.
# 15                 I don't want to make any mistakes.
# 16                And you put it on top of ice cream.
# 17                            I guess he really went.
# 18                                  I do not want it.
# 19                     They put a lot of money in it.
# 20  You can't do anything about it, but that doesn...
# 21          The airport is too close to the building.
# 22                     He has a lot of friends there.
# 23                                I was hungry today.
# 24                             I can't see him often.
# 25                                   I am not a joke.
# 26                          It's a lot of work to do.
# 27                         You were still a good guy.
# 28                    I like watching them do tricks.
# 29       The water pours from the faucet to the sink.
# 30                                   I'm a big eater.
# 31          She was waiting for her friend to arrive.
# 32                    And the dogs are in a dog park.
# 33       You will have a great time playing the game.
# 34                          I don't know how to draw.
# 35                               I'm going to try it.
# 36                            I want a glass of wine.
# 37                           You were still a sailor.
# 38                 I don't want to go to the concert.
# 39                             They are human beings.
# 40                            She was always so busy.
# 41          I don't know if I want to go out tonight.
# 42  He was a big man and it was hard for him to fi...
# 43                         He needs to get some fuel.
# 44                            You are a jerk to them.
# 45                   We go the roads for a long time.
# 46                      I am going to the book store.
# 47                   They are a company that reports.
# 48                               I want to read them.
# 49                                 I had a good time.
#
#                                              rejected  chosen_reward  \
# 0                  You're not strong enough to do it.       0.168457
# 1                                   I do not need it.       0.130859
# 2             He is a great person and a good friend.       0.000873
# 3                              I like to play a game.       0.106567
# 4                        i think he's a great leader.       0.019669
# 5                            They are a good company.       0.030014
# 6   jesus is unable to leave and begins to scream ...       0.017563
# 7                    We were happy with our decision.       0.046631
# 8                                Jerry is a good guy.       0.003344
# 9   You can not go to the store, because you are n...       0.073730
# 10                                  I do not need it.       0.118225
# 11                               The room is too hot.       0.078369
# 12                              You will not like it.       0.043976
# 13                    You can't do anything about it.       0.037384
# 14                           I bought the green cake.       0.047485
# 15               I don't want to wait until tomorrow.       0.107849
# 16                 And you put it on a plate and eat.      -0.015434
# 17                 I guess he really go to the store.       0.008675
# 18                                  I do not need it.       0.130859
# 19                           They put a lot of stuff.       0.025284
# 20  You can't do anything about it, but that doesn...       0.037384
# 21                       The airport is too far away.       0.123535
# 22                           He has a lot of friends.       0.010567
# 23                                   I was so hungry.       0.073608
# 24                         I can't see her every day.       0.145020
# 25                                   I am not a fool.       0.101135
# 26                                It's a lot of work.       0.118469
# 27                         You were still a good man.       0.030533
# 28             I can tell that they are very excited.       0.054626
# 29                             The hose is now empty.       0.033752
# 30                                     I'm a monster.      -0.009079
# 31                    She was waiting for her friend.       0.037292
# 32  And the dogs are in the house and eat a lot of...       0.013863
# 33      You will have a great time playing the drums.       0.044373
# 34                     I mean these is drawing lines.       0.143066
# 35  I'm going to try to get the sexiest dress I ca...       0.118286
# 36                           I want a glass of water.       0.040161
# 37                         You were still a good man.       0.001908
# 38                    I don't want to go to the park.       0.143188
# 39                       They are still human beings.       0.094910
# 40                             She was just a person.       0.024521
# 41                           I don't know what to do.       0.164429
# 42                                  He was a big man.       0.120850
# 43                          He needs to get some gas.       0.010071
# 44                                    You are a jerk.       0.095276
# 45                             We go the roads while.       0.044312
# 46                       I am going to the bookstore.       0.060120
# 47                            They are a big company.       0.026688
# 48                      I am going to the book store.       0.037811
# 49                                I had a great time.       0.048065
#
#     rejected_reward    win   loss
# 0          0.165894   True  False
# 1          0.118225   True  False
# 2         -0.024979   True  False
# 3          0.196777  False   True
# 4          0.020905  False   True
# 5          0.030289  False   True
# 6         -0.031006   True  False
# 7          0.051208  False   True
# 8          0.010780  False   True
# 9          0.050934   True  False
# 10         0.118225  False   True
# 11         0.093384  False   True
# 12         0.043762   True  False
# 13         0.047699  False   True
# 14         0.044250   True  False
# 15         0.129639  False   True
# 16        -0.028091   True  False
# 17        -0.029099   True  False
# 18         0.118225   True  False
# 19         0.020615   True  False
# 20         0.041992  False   True
# 21         0.101379   True  False
# 22        -0.006866   True  False
# 23         0.076111  False   True
# 24         0.125000   True  False
# 25         0.106384  False   True
# 26         0.130737  False   True
# 27         0.021576   True  False
# 28         0.042816   True  False
# 29         0.052429  False   True
# 30         0.043976  False   True
# 31         0.024063   True  False
# 32         0.053131  False   True
# 33         0.024261   True  False
# 34         0.093445   True  False
# 35         0.101379   True  False
# 36         0.054901  False   True
# 37         0.021576  False   True
# 38         0.158203  False   True
# 39         0.086609   True  False
# 40         0.043610  False   True
# 41         0.180664  False   True
# 42         0.028839   True  False
# 43         0.007381   True  False
# 44         0.104309  False   True
# 45         0.016815   True  False
# 46         0.064209  False   True
# 47         0.054382  False   True
# 48         0.060120  False   True
# 49         0.041443   True  False
